# %%
class A:
    x = 1
    y = 2
    def __init__(self):
        self.z = 2

class B:
    p = 2
    def __init__(self):
        self.q = 3

a = A()
set(dir(A)) ^ set(dir(a))
# Out:
# {'z'}

# %%
set(dir(B)) ^ set(dir(a))
# Out:
# {'p', 'x', 'y', 'z'}

# %%
a.x, B.x
# Out:
# (1, 2)

# %%
a.x is B.x
# Out:
# False

# %%
dir(B)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'x']

# %%
a = [1,2,3,4]
type(a)
# Out:
# list

# %%
type(list)
# Out:
# type

# %%
list.__bases__
# Out:
# (object,)

# %%
a.__bases__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a.__bases__
#
# AttributeError: 'list' object has no attribute '__bases__'

# %%
a = A()
type(a)
# Out:
# __main__.A

# %%
type(A)
# Out:
# type

# %%
type(A())
# Out:
# __main__.A

# %%
class A:
    x = 1
    def y(self):
        print('y')

class C:
    def __init__(self):
        self.a = A()

c = C()
c.x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 11
#       8         self.a = A()
#      10 c = C()
# ---> 11 c.x
#
# AttributeError: 'C' object has no attribute 'x'

# %%
from requests import request

url  = 'https://search.shopping.naver.com/search/all'
params = {
    'query':'아이폰'
}
ua = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'

resp = request('GET', url, params=params, headers={'user-agent':ua})

# %%
resp.status_code, resp.reason
# Out:
# (200, 'OK')

# %%
resp.text
# Out:
# '<!DOCTYPE html><html lang="ko"><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><title>아이폰 : 네이버 쇼핑</title><link rel="shortcut icon" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240307-152233/img/favicon.ico"/><meta property="og:title" content="아이폰 : 네이버 쇼핑"/><meta property="og:image" content="https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png"/><meta property="og:description" content="&#x27;아이폰&#x27;의 네이버쇼핑 검색 결과입니다"/><meta name="next-head-count" content="7"/><link rel="preconnect" href="https://static.nid.naver.com"/><link rel="preconnect" href="https://lcs.naver.com"/><link rel="preconnect" href="http://shopping.phinf.naver.net"/><link rel="preconnect" href="https://ssl.pstatic.net"/><link rel="preconnect" href="https://shopping-phinf.pstatic.net"/><link rel="preconnect" href="https://volts.shopping.naver.com"/><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240307-152233/_next/stati
# ...

# %%
resp.headers, resp.request.headers
# Out:
# ({'date': 'Wed, 13 Mar 2024 14:25:22 GMT', 'content-type': 'text/html; charset=utf-8', 'transfer-encoding': 'chunked', 'etag': '"8e264-0Ilv+Ebqq40szNXKfiM1kGxeJws"', 'cache-control': 'private, no-cache, no-store, max-age=0, must-revalidate', 'vary': 'Accept-Encoding', 'content-encoding': 'gzip', 'accept-ch': 'Sec-CH-UA-Arch, Sec-CH-UA-Mobile, Sec-CH-UA-Model, Sec-CH-UA-Platform, Sec-CH-UA-Platform-Version, Sec-CH-UA, Sec-CH-UA-Full-Version-List, Sec-CH-UA-Bitness, Sec-CH-UA-Wow64', 'referrer-policy': 'unsafe-url', 'server': 'nfront'},
#  {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'})

# %%
from html import unescape

unescape(resp.text)
# Out:
# '<!DOCTYPE html><html lang="ko"><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><title>아이폰 : 네이버 쇼핑</title><link rel="shortcut icon" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240307-152233/img/favicon.ico"/><meta property="og:title" content="아이폰 : 네이버 쇼핑"/><meta property="og:image" content="https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png"/><meta property="og:description" content="\'아이폰\'의 네이버쇼핑 검색 결과입니다"/><meta name="next-head-count" content="7"/><link rel="preconnect" href="https://static.nid.naver.com"/><link rel="preconnect" href="https://lcs.naver.com"/><link rel="preconnect" href="http://shopping.phinf.naver.net"/><link rel="preconnect" href="https://ssl.pstatic.net"/><link rel="preconnect" href="https://shopping-phinf.pstatic.net"/><link rel="preconnect" href="https://volts.shopping.naver.com"/><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240307-152233/_next/static/css/e8
# ...

# %%
import re

# class = thumbnail_thumb__Bxb6Z linkAnchor
# href 가져오기
re.findall(r'<a .+? class="thumbnail_thumb__Bxb6Z linkAnchor" .+? href="(.+?)">', resp.text)
# Out:
# ['https://adcr.naver.com/adcr?x=vr1Se4a6mT84yUlwwlQrmP///w==...',
#  'https://adcr.naver.com/adcr?x=Uz3Ti1CdysTspTk5gX3SSf///w==...',
#  'https://cr.shopping.naver.com/adcr.nhn?x=Of5vJtanu4x8pN5PNGFkJv%2F%2F%2Fw%3D%3Dsmoapzi9G2PosSuzJIWPbrVXTrx5XKScUbyi6ESGid8QAjU5j3gjlMYsRq8%2BGHFpSxVvbPTnmu%2Fi%2BBPtltqWbEYQWhdmnS3iVGIQglzYUwlUcPZCldovCGt46rGDtM9kr2942Z%2FvCxzhLHzZw10TSgN9%2BKy%2Fm0d%2BgYWHtEf61Jo5CNclKwvLyA%2Fys%2F%2FHPPajLfjx6NhfiRK4CjujZvGvZXGNmcbgLr0lu2cCLGgyX7c%2BveCBZaqYtj1zvPLl5obaRs%2BGl1nNGeGvWhfbk4adljasJF1TG8DXvuOXRWh2aiSE1QmeK3ZPITzKHcbEnR%2BI8RGfc2r568EJIUkcYLk6vKDtQRKahdxKFG2Ij6LbVY0lXfqiCwBtPYYwEdSt6i2JAuLsJvYdaFCiYhU1r3drioHtDZ0YgASbTQ2H1MsH5zfEEc05LTibBt%2FawtKKLwCqn3wX6r9OXqwjbRgE6Z4hFZcJZxbZqPzaWcTLdc%2FLE7qjk2BLcbO8TS1q%2FIby4aOgc4tMil368FtKyKctjdNHRycuiIUCtqyiKXtK5wO7BvYzC0hiHfmfzmAI0X1cC502K2AKC7xMfogRMj0hH4kgpdwqviJtljEXFgoBpIXcrbzKiMDihGXgVsCJEaGBaNY%2BhBq7h9PA5SrIXrcWPClBGWw%3D%3D&amp;nvMid=42617437619&amp;catId=50001519',
# ...

# %%
temp = '<img width="140" height="140" alt="아이폰 13 미니 128GB [자급제]" src="https://shopping-phinf.pstatic.net/main_2903065/29030650586.20220317113150.jpg?type=f140">'
# developer에서 본 element
temp = '<img src="https://shopping-phinf.pstatic.net/20180724_27/6a487977-9071-4eeb-9da7-86b72cb1501c.jpg" alt="쿠팡" height="15"/>'
# resp.text에서 본 element

# 결국엔 js로 따로 보내줌

re.findall(r'<img src="(.+?)" .+?/>', resp.text)
# Out:
# ['https://shop-phinf.pstatic.net/20200313_258/1584079634711l09yc_PNG/21441177335514190_126187390.png',
#  'https://shopping-phinf.pstatic.net/20180724_27/6a487977-9071-4eeb-9da7-86b72cb1501c.jpg',
#  'https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240307-152233/img/search/platinum_v1.png',
#  'https://shopping-phinf.pstatic.net/20180724_27/6a487977-9071-4eeb-9da7-86b72cb1501c.jpg',
#  'https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240307-152233/img/search/platinum_v1.png']

# %%
from bs4 import BeautifulSoup

# %%
html = '''
<!-- Jun Hyeong Park 112980317 -->

<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="utf-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1" />


    <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.0/css/bootstrap.min.css">
    <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.0/jquery.min.js"></script>
    <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.0/js/bootstrap.min.js"></script>

	   <link href="app.css" rel="stylesheet">
     <title>CourseMan!</title>
  </head>
  <body>
    <h2 class='logo'>Course Man</h2>
    <div class="navbar_toggle">
      <i id = "icon" class=" glyphicon glyphicon-menu-hamburger"></i>
    </div>
    <nav class="navbar">
      <ul class="navbar_menu">
        <li>
          <a class='navbar_lists' style = "padding : 18px;"href = 'index.html'>00 Home</a>
        </li>
        <li>
          <a class='navbar_lists' style = "padding : 18px;" href = 'instructions.html'>01 Instructions</a>
        </li>
        <li>
          <a class='navbar_lists' style = "padding : 18px;" href = 'precourse.html'>02 Enter Previous Courses</a>
        </li>
        <li>
          <a class='navbar_lists' style = "padding : 18px;" href = 'selectcourse.html'>03 Select Courses</a>
        </li>
      </ul>
    </nav>
	  <p></p>
      <script>
        const ham = document.querySelector('.navbar_toggle');
        const menu = document.querySelector('.navbar');
        const aa = document.querySelector('.navbar_lists');
        const icon = document.getElementById('icon');

        ham.addEventListener('click', menus);
        

        function menus() {
          ham.classList.toggle('active');
          menu.classList.toggle('active');
          icon.classList.toggle('glyphicon-menu-hamburger');
          icon.classList.toggle('glyphicon-remove');
        }

        aa.forEach(nl => nl.addEventListener('click', remove));

        function remove() {
          ham.classList.remove('active');
          menu.classList.remove('active');
          icon.classList.toggle('glyphicon-remove');
          icon.classList.toggle('glyphicon-menu-hamburger');
        }
      </script>

  </body>
</html>
'''

# %%
dom = BeautifulSoup(html, 'html.parser')
dom
# Out:
# <!-- Jun Hyeong Park 112980317 -->
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.0/css/bootstrap.min.css" rel="stylesheet"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.0/jquery.min.js"></script>
# <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.0/js/bootstrap.min.js"></script>
# <link href="app.css" rel="stylesheet"/>
# <title>CourseMan!</title>
# </head>
# <body>
# <h2 class="logo">Course Man</h2>
# <div class="navbar_toggle">
# <i class="glyphicon glyphicon-menu-hamburger" id="icon"></i>
# </div>
# <nav class="navbar">
# <ul class="navbar_menu">
# <li>
# <a class="navbar_lists" href="index.html" style="padding : 18px;">00 Home</a>
# </li>
# <li>
# <a class="navbar_lists" href="instructions.html" style="padding : 18px;">01 Instructions</a>
# </li>
# <li>
# ...

# %%
dom2 = BeautifulSoup(html, 'lxml')
dom2
# Out:
# <!-- Jun Hyeong Park 112980317 --><!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.0/css/bootstrap.min.css" rel="stylesheet"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.0/jquery.min.js"></script>
# <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.0/js/bootstrap.min.js"></script>
# <link href="app.css" rel="stylesheet"/>
# <title>CourseMan!</title>
# </head>
# <body>
# <h2 class="logo">Course Man</h2>
# <div class="navbar_toggle">
# <i class="glyphicon glyphicon-menu-hamburger" id="icon"></i>
# </div>
# <nav class="navbar">
# <ul class="navbar_menu">
# <li>
# <a class="navbar_lists" href="index.html" style="padding : 18px;">00 Home</a>
# </li>
# <li>
# <a class="navbar_lists" href="instructions.html" style="padding : 18px;">01 Instructions</a>
# </li>
# <li>
# ...

# %%
dom3 = BeautifulSoup(html, 'html5lib')
dom3
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 dom3 = BeautifulSoup(html, 'html5lib')
#       2 dom3
#
# File c:\Users\purpl\anaconda3\lib\site-packages\bs4\__init__.py:248, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     246     builder_class = builder_registry.lookup(*features)
#     247     if builder_class is None:
# --> 248         raise FeatureNotFound(
#     249             "Couldn't find a tree builder with the features you "
#     250             "requested: %s. Do you need to install a parser library?"
#     251             % ",".join(features))
#     253 # At this point either we have a TreeBuilder instance in
#     254 # builder, or we have a builder_class that we can instantiate
#     255 # with the remaining **kwargs.
# ...

# %%
type(dom)
# Out:
# bs4.BeautifulSoup

# %%
dom.html.body
# Out:
# <body>
# <h2 class="logo">Course Man</h2>
# <div class="navbar_toggle">
# <i class="glyphicon glyphicon-menu-hamburger" id="icon"></i>
# </div>
# <nav class="navbar">
# <ul class="navbar_menu">
# <li>
# <a class="navbar_lists" href="index.html" style="padding : 18px;">00 Home</a>
# </li>
# <li>
# <a class="navbar_lists" href="instructions.html" style="padding : 18px;">01 Instructions</a>
# </li>
# <li>
# <a class="navbar_lists" href="precourse.html" style="padding : 18px;">02 Enter Previous Courses</a>
# </li>
# <li>
# <a class="navbar_lists" href="selectcourse.html" style="padding : 18px;">03 Select Courses</a>
# </li>
# </ul>
# </nav>
# <p></p>
# <script>
#         const ham = document.querySelector('.navbar_toggle');
#         const menu = document.querySelector('.navbar');
#         const aa = document.querySelector('.navbar_lists');
#         const icon = document.getElementById('icon');
#
#         ham.addEventListener('click', menus);
#
#
#         function menus() {
# ...

# %%
dom.html.a
# 첫번째 맞는 얘 return
# Out:
# <a class="navbar_lists" href="index.html" style="padding : 18px;">00 Home</a>

# %%
dom.a.attrs
# 첫번째 맞는 얘의 attr return
# Out:
# {'class': ['navbar_lists'], 'style': 'padding : 18px;', 'href': 'index.html'}

# %%
dom.a.get_text(), dom.a.attrs['href']
# Out:
# ('00 Home', 'index.html')

# %%
dom.li.find()
# 얘도 i가 가지고 있는 tag를 보여주는데
# 가장 첫번째 매치된 얘를 return
# Out:
# <a class="navbar_lists" href="index.html" style="padding : 18px;">00 Home</a>

# %%
dom.find_all('a')
# 맞는 값을 전체 다 가지고 옴 (html 파일 전체 긁음)

# dom.li.find_all() -> li 안에 있는 맞는 값을 모두 가져오는 것
# Out:
# [<a class="navbar_lists" href="index.html" style="padding : 18px;">00 Home</a>,
#  <a class="navbar_lists" href="instructions.html" style="padding : 18px;">01 Instructions</a>,
#  <a class="navbar_lists" href="precourse.html" style="padding : 18px;">02 Enter Previous Courses</a>,
#  <a class="navbar_lists" href="selectcourse.html" style="padding : 18px;">03 Select Courses</a>]

# %%
dom.find_all(attrs={'href':'index.html'})
# 완전 일치만 가능한 거 같다
# Out:
# [<a class="navbar_lists" href="index.html" style="padding : 18px;">00 Home</a>]

# %%
dom.ul.find_all(recursive=False)
# Out:
# [<li>
#  <a class="navbar_lists" href="index.html" style="padding : 18px;">00 Home</a>
#  </li>,
#  <li>
#  <a class="navbar_lists" href="instructions.html" style="padding : 18px;">01 Instructions</a>
#  </li>,
#  <li>
#  <a class="navbar_lists" href="precourse.html" style="padding : 18px;">02 Enter Previous Courses</a>
#  </li>,
#  <li>
#  <a class="navbar_lists" href="selectcourse.html" style="padding : 18px;">03 Select Courses</a>
#  </li>]

# %%
dom.ul.find_all(recursive=True)
# 얘 왜 두번 됨?
# 부모 자식 둘 다 보기 때문임?
# YES, 자식인 li, a 둘 다 봐서 그럼
# Out:
# [<li>
#  <a class="navbar_lists" href="index.html" style="padding : 18px;">00 Home</a>
#  </li>,
#  <a class="navbar_lists" href="index.html" style="padding : 18px;">00 Home</a>,
#  <li>
#  <a class="navbar_lists" href="instructions.html" style="padding : 18px;">01 Instructions</a>
#  </li>,
#  <a class="navbar_lists" href="instructions.html" style="padding : 18px;">01 Instructions</a>,
#  <li>
#  <a class="navbar_lists" href="precourse.html" style="padding : 18px;">02 Enter Previous Courses</a>
#  </li>,
#  <a class="navbar_lists" href="precourse.html" style="padding : 18px;">02 Enter Previous Courses</a>,
#  <li>
#  <a class="navbar_lists" href="selectcourse.html" style="padding : 18px;">03 Select Courses</a>
#  </li>,
#  <a class="navbar_lists" href="selectcourse.html" style="padding : 18px;">03 Select Courses</a>]

# %%
dom.ul.find_all(limit=2)
# Out:
# [<li>
#  <a class="navbar_lists" href="index.html" style="padding : 18px;">00 Home</a>
#  </li>,
#  <a class="navbar_lists" href="index.html" style="padding : 18px;">00 Home</a>]

# %%
dom.a.find_parent(name='ul')
# 부모인 ul을 찾는데 ul이 가지고 있는 tag 모두를 보여줌
# Out:
# <ul class="navbar_menu">
# <li>
# <a class="navbar_lists" href="index.html" style="padding : 18px;">00 Home</a>
# </li>
# <li>
# <a class="navbar_lists" href="instructions.html" style="padding : 18px;">01 Instructions</a>
# </li>
# <li>
# <a class="navbar_lists" href="precourse.html" style="padding : 18px;">02 Enter Previous Courses</a>
# </li>
# <li>
# <a class="navbar_lists" href="selectcourse.html" style="padding : 18px;">03 Select Courses</a>
# </li>
# </ul>

# %%
dom.a.find_parents(name='ul', limit=1)
# Out:
# [<ul class="navbar_menu">
#  <li>
#  <a class="navbar_lists" href="index.html" style="padding : 18px;">00 Home</a>
#  </li>
#  <li>
#  <a class="navbar_lists" href="instructions.html" style="padding : 18px;">01 Instructions</a>
#  </li>
#  <li>
#  <a class="navbar_lists" href="precourse.html" style="padding : 18px;">02 Enter Previous Courses</a>
#  </li>
#  <li>
#  <a class="navbar_lists" href="selectcourse.html" style="padding : 18px;">03 Select Courses</a>
#  </li>
#  </ul>]

# %%
dom.li.find_next_sibling()
# 하나만 건너뛸 수 있음
# Out:
# <li>
# <a class="navbar_lists" href="instructions.html" style="padding : 18px;">01 Instructions</a>
# </li>

# %%
dom.li.find_next_siblings()
# 다음 sibling 전체 의미
# Out:
# [<li>
#  <a class="navbar_lists" href="instructions.html" style="padding : 18px;">01 Instructions</a>
#  </li>,
#  <li>
#  <a class="navbar_lists" href="precourse.html" style="padding : 18px;">02 Enter Previous Courses</a>
#  </li>,
#  <li>
#  <a class="navbar_lists" href="selectcourse.html" style="padding : 18px;">03 Select Courses</a>
#  </li>]

# %%
dom.li.find_previous_sibling()

# %%
dom.li.find_previous_siblings()
# 가장 첫번째 li가 이전 sibling이 없기에 아무것도 안나옴
# Out:
# []

# %%
# 오후
class A:
    x = 1
    def y(self):
        print('y')

class C:
    def __init__(self):
        self.a = A()

# %%
c = C()
c.x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [81], in <cell line: 2>()
#       1 c = C()
# ----> 2 c.x
#
# AttributeError: 'C' object has no attribute 'x'

# %%
class C:
    def __init__(self):
        self.a = A()
    def __getattr__(self, x):
        print(x)

c = C()
c.x
# Out:
# x
