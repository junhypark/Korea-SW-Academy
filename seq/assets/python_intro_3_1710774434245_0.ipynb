# %%
def x(a):
    print('a')

b = [x]
b[0](4)

# %%
#본래의 등차수열 함수
def t(x):
    if x==1:
        return 1
    return t(x-1)+2

t(3)
#Recursion 사용하지 마라 왜? stack에 계속 쌓이는데 python은 recursion ellimination을 지원해주지 않기 때문에
#dynamic programming tech로 해결

#Python은 수학 언어이기 때문에 조건문보다 조건식을 더 많이 쓴다
#Python은 무엇을 만드는 것이 어떻게 만드는 것보다 더 중요하다
#Python is most definitely not a "pure" functional programming language

#함수형 프로그래밍 모듈 3가지 존재한다
#itertools, functools, operator 이 존재한다

#함수형 프로그래밍은 flow control에 좋다
#for가 함수형 패러다임의 대표격

#효율적으로 for 사용하는 법
#객체 지향의 4가지 특징 중 하나
#Encapsulation - 이름으로 묶는다 / 이름에 집중한다
#코드를 함수로 정의하는 것 즉, 하나의 함수의 이름으로 정의하는 것이 encapsulation이다
#클래스의 encapsulation과 함수의 encapsulation은 서로 다르다

#함수의 경우에는 밖의 변수가 접근 가능하다 하지만 함수 안에서 선언된 변수는 밖에서 접근이 불가능하다
#접근 제한이 걸려있다 (scope)
#LEGB - local encourage global built in 로컬에서는 encourage 접근 가능하고 built in 접근 가능하지만 반대는 불가능하다
#함수 내의 영역은 local 영역이라고 한다
#먼저 로컬에서 변수를 찾고 없으면 글로벌의 것을 가져온다
b = 1
def a():
    ttt = 3
    b = 2
    return b
#>>> b는 2가 결과값을 나온다
sum = 0 #built-ins를 안가져오고 먼저 글로벌에 존재하는 sum을 불러온다
#del => 변수를 없애는 거지만 LEGB룰에 의해서 global에 존재하는 sum이라는 변수를 먼저 지운다
# temp = []
# for i in range(10000000):
#     temp.append(i)
# temp

#or

[i for i in range(10000000)]
#얘가 더 빠르고 메모리 낭비도 적다
#이런 한줄 "식"으로 만들어서 효율적으로 사용하는 것을 comprehension이라고 한다

#여러 개의 값을 쉽게 만들거나, 변화시킬때 사용한다 (반복과 결합)

# %%
A = [i for i in range(10)]
#이때 i는 global이 아니다 comprehension의 local 영역에 안에 있는 indicator이기 때문에

[b+1 for b in A]
#얘를 이렇게 바꾸면...

[b+1 for b in range(10)]

#조건도 붙일 수 있다
[b for b in range(10) if b%2==0]
#else를 원하면?

[b if b%2==0 else '' for b in range(10)]

#중복으로 만드는것
[(a,b) for b in range(10) for a in range(11,20)]
#collection = [d if condition(d) else modify(d) for d in data_set]
#딥러닝 시에는 comprehension이 오히려 가상 메모리까지 잡아먹기 때문에 문제가 될 떄도 있다 (큰 프로젝트에서)

#Comprehension - list, set, dictionary 3가지 종류가 존재한다
{b+1 for b in a} #이렇게
#Mutable인 얘만 comprehension을 지원한다

# %%
#Mutable에 대해 이해보자
#List, Set, Dictionary
#메모리 구조
#a=1에서 1의 타입을 자동으로 체크한다
#dynamic typing? 본래에는 int면 int 만큼 메모리를 할당하지만
#Python은 값에 따라서 동적으로 메모리를 할당해서 주기 때문이다
a = 1
a = ''
#따라서, 이렇게 재할당이 가능하다
a=1000
b=1000
#a에 저장된 메모리와 b에 저장된 메모리는 다르지 맞지
#근데 이게 당연한게 아니다?
#a=256, b=256 하면 같은 memory bunch가 나온다
#256~ -5 서로 같은 메모리를 공유한다 왜? 자주 쓰는 값들은 cache라는 것을 사용해서 그럼
#a == b는 값이 같은지 아닌지 체크하는 친구이고 is는 메모리가 같은지 아닌지 체크하는 것이다

#Mutable = 메모리 재할당하지 않고 변형 가능한 특성
#List
x = [1.2.3]
x.append(4)
id(x)
#x는 원래거를 더하거나 바꿔도 재할당 즉, 메모리 주소가 바뀌지 않기 때문에 새로 할당하지 않기에 좋다

#Immutable
#List <-> tupple
#Set <-> frozenset
#dictionary 는 반대가 없지만 library를 통해서 namedtupple 혹은 OrderedDict를 사용 가능하다

aa={'a':1}
aa['b'] = 2 #는 가능하다 왜? dict는 key 영역을 할당시키고 hash이기 때문에 value를 넣기 떄문에 이게 가능하다

# %%
(i for i in range(10))  #generator
#뽑는 것을 만들어야하는데 앞에서부터 뽑게 만들었다
#(iterable 중간단계 - 뽑을 때)
#왜 앞에서부터 뽑느지가 정해져있나? 효율적으로 하기 위해서
#한발가서 한명 뽑고 한발가서 한명 뽑고...
#한발가서 한 명 뽑고 두발가서 한명 뽑고 다시 한발 뒤로 가서 한명뽑고..
#비효율적이다 후자가
#실제로는 iterator가 한칸 씩 가서 뽑는 것 까지 한다
#iterator는 사용자 편의성

#b=iter(a)로 하면 iterator로 바꾼다 즉, 한개씩 뽑을 수 있게 만들어준다
#next(b)는 첫번째 index 0을 뽑는다
#iterator와 generator는 친척관계지만 만드는 방식이 다르다. 하지만 같은 역할이다

#generator는 만드는 방식이 2개
c = (i for i in range(10))
next(c) #iterator
#Generator 만드는 방식
#1. tupple로 comprehension을 사용할 때
#2. yield를 사용할때

def z():
    yield 1
    yield 2
zz = z()
zz
next(zz) #로 뽑을 수 있다

#Comprehension 과 iterator와 generator는 다르다
#iterator와 generator는 여러개에서 한 개씩 뽑는 것
#Comprehension은 여러개의 값을 한번에 변화시키거나 뽑을 때
#iterator와 generator는 서로 다른 이유
#데이터를 한개씩 추출하기 위해서
#iter라는 문법을 사용해서 iterator라고 명명
#yield를 사용하면 자유롭게 뽑을 수 있다?
#데이터 구조를 자유롭게 설정하고 동적으로 만들고 싶을때는 generator를 사용한다

#higher-order function 함수를 인자로 넣고 return 가능한 것
#함수를 리턴한다 즉, recursion

# %% [markdown]
# 수학적 함수
# 입력이 없으면 함수가 아니다
#
# 파이썬은 리턴이 없으면 None을 내부적으로 붙여준다
#
# 함수형 언어의 특징
# 1. 형식적 증명 가능성
#
#
# 함수형 프로그래밍 언어는 최초 인공즈니으 언어인 lisb가 함수형 프로그래밍 언어
#
# for 함수형 패러다임으로 만들어짐
#
# 함수는 firstclass - 값을 의미함, 함수는 firstclass 따라서, a = print 와 같은 일들 일잉어날 수 있다
#
# 리스트 안에도 집어넣을 수 있다
#
# 함수는 higher-order라고 한다 - firstclass와 비슷하다 / 함수를 인자로 사용하고 리턴할 수 있는 함수

# %% [markdown]
# # Python
#
# Do not use Recursion
#
# Why? it keeps stack on the stack but python does not give tail-recursion elimination
#
# How we have to solve it?
#
# Using dynamic programming tech
#
# ### Expression
#
# Python prefer to use expression not a statement
#
# Python is important to make what not how
#
# "Python is most definitely not a "pure" functional programming language"
#
# ### Functional Paradaigm
#
# There are 3 functional programming module
#
# 1. itertools
# 2. functools
# 3. operator
#
# Functional programming is much better at flow control
#
# "for" is one of them
#
# ##### How to use for efficiently?
#
# 1. Encapsulation - bind by name and focus the name
# 2. Delcare by function - Indeed, encapsulation is declaration into one name of function
#
# Class encapsulation and function encapsulation is different
#
# ### Scope
#
# Each variable type has different access
#
# Function can access to the variable that is out of the function
#
# However, from the out of function, the code cannot access to the inner function variable
#
# Law of scope? **LEGB**
#
# Local > Enclosed function locals > Global > Built-in
#
# Inner function is local access
#
# Seek from the local and if there is not, we take from the global
#
# ```
# b = 1
# def a():
#     ttt = 3
#     b = 2
#     return b
# ```
#
# The result will be 2
#
# Similar Example
#
# ```
# sum = 0
# sum
# ```
#
# Show the value 0
#
# Why? sum is built-in function but in the local there is a sum indicator
#
# ### Comprehension
#
# ex)
#
# ```
# [i for i in range(100)]
# ```
#
# This is much faster and efficient in memory usage
#
# Such example, using a one line expression efficiently is calles **Comprehension**
#
# We use when making various values easily or modify
#
# In this case, "i" is not a global because it is indicator inside of local
#
# We can also put conditions to it
#
# ```
# [b if b%2 == 0 else '' for b in range(10)]
# ```
#
# When handling various values...
#
# ```
# [(a,b) for b in range(10) for a in range(11,20)]
# ```
#
# So the structure will be
#
# **collection = [d if condition(d) else modify(d) for d in data_set]**
#
# For Deep Learning, comprehension uses virtual memory that deep learning has to use so that comprehension is a problem at this situation
#
# We can use three types when using Comprehension
#
# 1. List
# 2. Set
# 3. Dictionary
#
# like...
#
# ```
# {b+1 for b in a}
# ```
#
# **Only mutable support comprehenstion**
#
# ### Mutable
#
# We have to understand the memory structure before that
#
# If we give ```a=1000``` and ```b=1000```, although we modify the b value, a value does not change
#
# However, if we give a to 256 and b to 256 those show the same memory address
#
# ```
# a = 256
# b = 256
# id(a)
# id(b)
# ```
#
# In this regard, ```a==b``` is checking whether those have same value and ```a is b``` is checking whether those have same memory address
#
# What is Mutable?
#
# **Mutable is a characteristic without re-allocation, able to modify the values**
#
# ```
# x = [1,2,3]
# x.append(4)
# id(x)
# ```
#
# The id of x does not change
#
# What about Immutable?
#
# 1. List <-> tupple
# 2. Set <-> frozenset
# 3. Dictionary <-> namedtupple, OrderedDict, etc. (from other library)
#
# For more, we can put dictionary like...
#
# ```
# aa = {'a':1}
# aa['b'] = 2
# ```
#
# It is possible. Why? Since dict allocate key area, is hash, and put value
#
# ### Generator
#
# To understand generator, we have to compare with iterator
#
# Iterator - Build to select from first or last
#
# In order to make indicator to be iterable, we put ```iter(a)```
#
# ```next(a)``` pick up the first value of a
#
# Iterator and generator are similar and perform same role, but ways to make is different
#
# Ways to make generator
# 1. Make tupple with comprehension
# ```
# c = (i for i in range(10))
# ```
#
# 2. Using ```yield```
# ```
# def z():
#     yield 1
#     yield 2
# zz = z()
# zz
# ```
#
# Why they are different?
#
# In order to pick up datum from data
#
# Using yield, we can set various data type and make dynamically
#
# ##### Comprehension vs iterator, generator
#
# Comprehension - Modify or Select various values at once
#
# Iterator, Generator - From various values, pick one value
#
# ### Higher-order function
#
# Put function as argument and return function
#
# If there is no return, automatically return None
#
# Function is firstclass - Means value, as firstclass function can be ```a=print```
#
# Also, we can put function into list
#
# Function is called higher-order which is similar with firstclass
#
# Higher-order - Use function as an argument and return the function
#
# ```
# def y():
#     print('y')
#     return y
# ```
#
# We can call y like..
#
# ```
# y
# y()
# y()()
# y()()()
# y()()()()...
# ```
